# %%
#Import the necessary methods from tweepy library
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
import pymongo
import json
from pymongo import MongoClient
import pprint as pp

client = pymongo.MongoClient("mongodb://localhost:27017/")
db = client.MinorProject
mycol = db.gunlaws2
mycol2 = db.gunlawsAllTweetsText2
#Variables that contains the user credentials to access Twitter API+ 
access_token = ""
access_token_secret = ""
consumer_key = ""
consumer_secret = ""

file=open("gunlaws2.json",'a')

#This is a basic listener that just prints received tweets to stdout.
class StdOutListener(StreamListener):

    def on_data(self, data):
        record=json.loads(data)
        mycol.insert_one(record)
        
        try:
            if 'text' in record:
                if record['text'][:4] != "RT @":
                    dic = {}
                    dic['id'] = record["id_str"]
                    dic['text'] = record["text"]
                    mycol2.update(dic,dic,upsert=True)
                elif record['text'][:4] == "RT @":
                    if 'retweeted_status' in record:
                        dic = {}
                        dic['id'] = record['retweeted_status']["id_str"]
                        if 'extended_tweet' in record['retweeted_status']:
                            dic["text"] = record['retweeted_status']['extended_tweet']['full_text']
                            mycol2.update(dic,dic,upsert=True)
                        else:
                            dic["text"] = record['retweeted_status']['text']
                            mycol2.update(dic,dic,upsert=True)
        
        except Exception as e:
            print(e)
            
        #print (data)
        file.write(data)
        return True

    def on_error(self, status):
        print (status)


if __name__ == '__main__':

    #This handles Twitter authetification and the connection to Twitter Streaming API
    l = StdOutListener()
    auth = OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)
    
    stream = Stream(auth, l)

    #This line filter Twitter Streams to capture data by the keywords: 'python', 'javascript', 'ruby'
    #stream.filter(track=['#brexit','#brexitmeansbrexit','#brexitmemes','#brexitshambles','#brexitblues','#brexitbritain','#brexitchaos','#brexitvote','#brexitparty','#brexitdebate','#brexitdeal','#brexitsucks','#brexitmarch','#brexitday','#brexiteers','#brexitbetrayal','#brexiteer','#brexitnegotiations','#brexitart','#brexitometer','#stopbrexit'],languages=["en"])
    track=['#antigun','#gunviolence','#guncontrol','#gunskillpeople','#marchforourlives','#gunshooting','#guncontrolnow','#safety','#tcot','#firearms','#neveragain','#nra','#MomsDemandAction','#stopgunviolence','#NoMoreNRA','#guns','#massshooting']
    stream.filter(track=track,languages=["en"])
# Out:
# /home/tushit/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: DeprecationWarning: update is deprecated. Use replace_one, update_one or update_many instead.
# /home/tushit/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: DeprecationWarning: update is deprecated. Use replace_one, update_one or update_many instead.
# /home/tushit/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: DeprecationWarning: update is deprecated. Use replace_one, update_one or update_many instead.
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     293         try:
# --> 294             return self.connection.recv_into(*args, **kwargs)
#     295         except OpenSSL.SSL.SysCallError as e:
#
# ...

# %%
#Import the necessary methods from tweepy library
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
import pymongo
import json
from pymongo import MongoClient
import pprint as pp

client = pymongo.MongoClient("mongodb://localhost:27017/")
db = client.MinorProject
mycol = db.gunlaws1
mycol2 = db.gunlawsAllTweetsText1
#Variables that contains the user credentials to access Twitter API+ 
access_token = "1482734010-f1lDNUrYX88H4XWZ00zoAAi5l9JMjOOQ4WiphFO"
access_token_secret = "hy0eo7HAOg9UfMwUapnSUdA1bNSfgKPFOE6zh8yDidS42"
consumer_key = "HuSgpu3fy4UotSfI7s2dMPxs3"
consumer_secret = "Ukb4DeTncoJ6Dw3gTR9KlkNA7zRP3qGX0CCZ9lYleGIjQR2Z8E"

file=open("gunlaws1.json",'a')

#This is a basic listener that just prints received tweets to stdout.
class StdOutListener(StreamListener):

    def on_data(self, data):
        record=json.loads(data)
        mycol.insert_one(record)
        
        try:
            if 'text' in record:
                if record['text'][:4] != "RT @":
                    dic = {}
                    dic['id'] = record["id_str"]
                    dic['text'] = record["text"]
                    mycol2.update(dic,dic,upsert=True)
                elif record['text'][:4] == "RT @":
                    if 'retweeted_status' in record:
                        dic = {}
                        dic['id'] = record['retweeted_status']["id_str"]
                        if 'extended_tweet' in record['retweeted_status']:
                            dic["text"] = record['retweeted_status']['extended_tweet']['full_text']
                            mycol2.update(dic,dic,upsert=True)
                        else:
                            dic["text"] = record['retweeted_status']['text']
                            mycol2.update(dic,dic,upsert=True)
        
        except Exception as e:
            print(e)
            
        #print (data)
        file.write(data)
        return True

    def on_error(self, status):
        print (status)


if __name__ == '__main__':

    #This handles Twitter authetification and the connection to Twitter Streaming API
    l = StdOutListener()
    auth = OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)
    
    stream = Stream(auth, l)

    #This line filter Twitter Streams to capture data by the keywords: 'python', 'javascript', 'ruby'
    #stream.filter(track=['#brexit','#brexitmeansbrexit','#brexitmemes','#brexitshambles','#brexitblues','#brexitbritain','#brexitchaos','#brexitvote','#brexitparty','#brexitdebate','#brexitdeal','#brexitsucks','#brexitmarch','#brexitday','#brexiteers','#brexitbetrayal','#brexiteer','#brexitnegotiations','#brexitart','#brexitometer','#stopbrexit'],languages=["en"])
    track=['#ProGun','#2ADefender','#Ar15','#2ndAmendment','#Libertarian','#goodgun','#Prolife','#ProGod','#Freedom','#2A','#pewpewlife','#SecondAmendment','#gunrights','#FireArmsDaily','#Gunsdaily','#gunsmithing','#gunsmithproud']
    stream.filter(track=track,languages=["en"])
