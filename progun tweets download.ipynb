# %%
import re
import pandas as pd
from sklearn import model_selection
from sklearn.model_selection import KFold
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import json
print("Setup Complete")
# Out:
# Setup Complete

# %%
import tweepy
import json
import csv #Import csv
auth = tweepy.auth.OAuthHandler("","")
auth.set_access_token("","")

api = tweepy.API(auth,wait_on_rate_limit=True)

# Open/create a file to append data to
csvFile = open('progun.csv', 'a',encoding='utf-8')
f=open('pro_full_data.txt','a')
#f1=open('onlytextofgunlaws.csv','a')
#Use csv writer
csvWriter = csv.writer(csvFile)
track=['#ProGun','#2ADefender','#Ar15','#2ndAmendment','#Libertarian','#goodgun','#Prolife','#ProGod','#Freedom','#2A','#pewpewlife','#SecondAmendment','#gunrights','#FireArmsDaily','#Gunsdaily','#gunsmithing','#gunsmithproud']
for item in track:    
    for tweet in tweepy.Cursor(api.search,q = item,lang = "en", tweet_mode='extended').items():
        #print(type(tweet))
        f.write(json.dumps(tweet._json))
        #f1.write('{},{}'.format(dic['date'],dic['text']))
        #print('{},{}'.format(tweet.created_at,tweet.full_text))
        #print('\n')
        # Write a row to the CSV file. I use encode UTF-8
        csvWriter.writerow([tweet.id,tweet.created_at,tweet.full_text])
        #print(tweet.created_at,tweet.text)
csvFile.close()
f.close()
f1.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-b1717394ea76> in <module>
#      15 track=['#ProGun','#2ADefender','#Ar15','#2ndAmendment','#Libertarian','#goodgun','#Prolife','#ProGod','#Freedom','#2A','#pewpewlife','#SecondAmendment','#gunrights','#FireArmsDaily','#Gunsdaily','#gunsmithing','#gunsmithproud']
#      16 for item in track:
# ---> 17     for tweet in tweepy.Cursor(api.search,q = item,lang = "en", tweet_mode='extended').items():
#      18         #print(type(tweet))
#      19         f.write(json.dumps(tweet._json))
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/cursor.py in __next__(self)
#      47
#      48     def __next__(self):
# ---> 49         return self.next()
#      50
#      51     def next(self):
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/cursor.py in next(self)
#     195         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     196             # Reached end of current page, get the next page...
# --> 197             self.current_page = self.page_iterator.next()
#     198             self.page_index = -1
#     199         self.page_index += 1
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/cursor.py in next(self)
#     106
#     107         if self.index >= len(self.results) - 1:
# --> 108             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kargs)
#     109
#     110             if hasattr(self.method, '__self__'):
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     248             return method
#     249         else:
# --> 250             return method.execute()
#     251
#     252     # Set pagination mode
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/binder.py in execute(self)
#     162                                     if self.wait_on_rate_limit_notify:
#     163                                         log.warning("Rate limit reached. Sleeping for: %d" % sleep_time)
# --> 164                                     time.sleep(sleep_time + 5)  # sleep for few extra sec
#     165
#     166                 # if self.wait_on_rate_limit and self._reset_time is not None and \
#
# KeyboardInterrupt:
